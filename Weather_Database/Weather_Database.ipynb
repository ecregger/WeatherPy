# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low =-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# ['chuy', 'hermanus', 'jamestown', 'cape town', 'maniitsoq', 'itaituba', 'tsihombe', 'tasiilaq', 'mataura', 'hilo', 'chokurdakh', 'albany', 'rikitea', 'ushuaia', 'lolua', 'poum', 'sao joao da barra', 'vorukh', 'gat', 'mukhen', 'attawapiskat', 'butaritari', 'tuatapere', 'mitsamiouli', 'airai', 'yellowknife', 'illoqqortoormiut', 'santa maria da vitoria', 'punta arenas', 'haines junction', 'hambantota', 'busselton', 'college', 'kapaa', 'barrow', 'matveyevka', 'jiddah', 'ixtapa', 'codrington', 'mar del plata', 'mahebourg', 'avarua', 'bredasdorp', 'klaksvik', 'mehamn', 'yaan', 'kitimat', 'poros', 'khatanga', 'taolanaro', 'tuktoyaktuk', 'mao', 'upernavik', 'port hedland', 'nanortalik', 'blagoyevo', 'saint george', 'kodiak', 'meulaboh', 'touros', 'candolim', 'tema', 'aflu', 'nikolskoye', 'rungata', 'hobart', 'priponesti', 'anuchino', 'candido de abreu', 'katherine', 'launceston', 'esperance', 'bull savanna', 'qaanaaq', 'fortuna', 'te anau', 'provideniya', 'conceicao do araguaia', 'shumskiy', 'bluff', 'new norfolk', 'hunza', 'ilulissat', 'avera', 'kenai', 'saint-philippe', 'pevek', 'oriximina', 'west wendover', 'dikson', 'buta', 'ulladulla', 'hofn', 'dogondoutchi', 'la crosse', 'bagn', 'sambava', 'yar-sale', 'batagay', 'nome', 'tazovskiy', 'ponta do sol', 'iqaluit', 'kavaratti', 'port alfred', 'zhanaozen', 'nizhneyansk', 'dudinka', 'carnarvon', 'saldanha', 'ilo', 'lebu', 'san patricio', 'hovd', 'vaitupu', 'salinas', 'tiksi', 'seoul', 'taoudenni', 'torbay', 'constitucion', 'fairbanks', 'lata', 'ternate', 'jalu', 'verin', 'puerto ayora', 'richards bay', 'saleaula', 'at-bashi', 'atuona', 'kawalu', 'port lincoln', 'zaysan', 'bethel', 'maykain', 'broome', 'tumannyy', 'vaini', 'elliot lake', 'san quintin', 'hirado', 'east london', 'ribeira grande', 'thompson', 'inhambane', 'camacha', 'gwanda', 'karratha', 'kropotkin', 'mys shmidta', 'bilibino', 'kaitangata', 'victoria', 'stromness', 'kollam', 'pisco', 'tezu', 'kloulklubed', 'kaberamaido', 'belushya guba', 'lagos', 'adrar', 'bereda', 'mount isa', 'newala', 'sentyabrskiy', 'poronaysk', 'chivilcoy', 'jinchang', 'rawson', 'ulaangom', 'saint-joseph', 'ancud', 'dicabisagan', 'vardo', 'cidreira', 'barentsburg', 'innisfail', 'geraldton', 'nuuk', 'dunedin', 'chapais', 'komsomolskiy', 'castro', 'belaya gora', 'banjar', 'tarudant', 'ritchie', 'lazaro cardenas', 'egvekinot', 'donskoy', 'port elizabeth', 'krasnoselkup', 'kamenskoye', 'mecca', 'lufilufi', 'melfi', 'praia da vitoria', 'bathsheba', 'luderitz', 'bukama', 'bozoum', 'faanui', 'lagoa', 'zhigansk', 'cabo san lucas', 'colares', 'nagornyy', 'tromso', 'narsaq', 'cayenne', 'butterworth', 'skelleftea', 'tura', 'alto araguaia', 'makaryev', 'rawannawi', 'amderma', 'lityn', 'xichang', 'mayo', 'yerbogachen', 'necochea', 'mount gambier', 'korla', 'arrifes', 'marsa matruh', 'cacapava do sul', 'zwettl', 'alice springs', 'kinshasa', 'waingapu', 'ebano', 'kachug', 'cherskiy', 'santa maria', 'hithadhoo', 'pacific grove', 'hirara', 'kayes', 'half moon bay', 'oranjemund', 'etchoropo', 'isangel', 'nipawin', 'alofi', 'katsuura', 'darhan', 'hino', 'champerico', 'gawler', 'umm kaddadah', 'tilichiki', 'grand river south east', 'galiwinku', 'muros', 'zhuozhou', 'suda', 'caravelas', 'chikoy', 'sitka', 'opuwo', 'kupang', 'vigrestad', 'pangody', 'longyearbyen', 'daru', 'riyadh', 'vao', 'dhidhdhoo', 'broken hill', 'bonthe', 'georgetown', 'salinopolis', 'farafangana', 'fort frances', 'naugarzan', 'samarai', 'talnakh', 'nova olimpia', 'russell', 'porbandar', 'vanimo', 'zhuhai', 'antananarivo', 'ibra', 'kangaatsiaq', 'bengkulu', 'margate', 'norman wells', 'ingham', 'ahipara', 'kamenka', 'ukiah', 'labuhan', 'coahuayana', 'azovo', 'tiznit', 'hualmay', 'portland', 'souillac', 'leningradskiy', 'zhezkazgan', 'hihifo', 'luwuk', 'floro', 'palabuhanratu', 'srednekolymsk', 'sahrak', 'bairiki', 'port moresby', 'kahului', 'pangnirtung', 'novoagansk', 'qasigiannguit', 'kajaani', 'inderborskiy', 'adet', 'kapuskasing', 'asfi', 'surt', 'mangrol', 'ewa beach', 'tecoanapa', 'xixiang', 'gusau ...

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?"
urlunits = "&units=imperial"
urlAPIkey = "&APPID=" + weather_api_key

#cities = ['san jose', 'louisville', 'turkistan', 'boston']

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") + urlAPIkey + urlunits
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["main"]
        # Convert the date to ISO standard.
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Desc": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | maniitsoq
# Processing Record 6 of Set 1 | itaituba
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 1 | poum
# Processing Record 17 of Set 1 | sao joao da barra
# Processing Record 18 of Set 1 | vorukh
# Processing Record 19 of Set 1 | gat
# Processing Record 20 of Set 1 | mukhen
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | tuatapere
# Processing Record 24 of Set 1 | mitsamiouli
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | santa maria da vitoria
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | hambantota
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | matveyevka
# Processing Record 37 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 1 | ixtapa
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | mehamn
# Processing Record 46 of Set 1 | yaan
# Processing Record 47 of Set 1 | kitimat
# Processing Record 48 of Set 1 | poros
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | mao
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | port hedland
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | blagoyevo
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | meulaboh
# Processing Record 10 of Set 2 | touros
# Processing Record 11 of Set 2 | candolim
# Processing Record 12 of Set 2 | tema
# Processing Record 13 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | priponesti
# Processing Record 18 of Set 2 | anuchino
# Processing Record 19 of Set 2 | candido de abreu
# Processing Record 20 of Set 2 | katherine
# Processing Record 21 of Set 2 | launceston
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | bull savanna
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | te anau
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | conceicao do araguaia
# Processing Record 29 of Set 2 | shumskiy
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | avera
# Processing Record 35 of Set 2 | kenai
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | oriximina
# Processing Record 39 of Set 2 | west wendover
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | buta
# Processing Record 42 of Set 2 | ulladulla
# Processing Record 43 of Set 2 | hofn
# Processing Record 44 of Set 2 | dogondoutchi
# Processing Record 45 of Set 2 | la crosse
# Processing Record 46 of Set 2 | bagn
# Processing Record 47 of Set 2 | sambava
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | batagay
# Processing Record 50 of Set 2 | nome
# Processing Record 1 of Set 3 | tazovskiy
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | zhanaozen
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | dudinka
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | ilo
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | hovd
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | salinas
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | seoul
# Processing Record 19 of Set 3 | taoudenni
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | lata
# Processing Record 24 of Set 3 | ternate
# Processing Record 25 of Set 3 | jalu
# Processing Record 26 of Set 3 | verin
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | richards bay
# Processing Record 29 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 3 | at-bashi
# Processing Record 31 of Set 3 | atuona
# Processing Record 32 of Set 3 | kawalu
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | zaysan
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | elliot lake
# Processing Record 41 of Set 3 | san quintin
# Processing Record 42 of Set 3 | hirado
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | inhambane
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | gwanda
# Processing Record 49 of Set 3 | karratha
# Processing Record 50 of Set 3 | kropotkin
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | victoria
# Processing Record 5 of Set 4 | stromness
# Processing Record 6 of Set 4 | kollam
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | tezu
# Processing Record 9 of Set 4 | kloulklubed
# Processing Record 10 of Set 4 | kaberamaido
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | lagos
# Processing Record 13 of Set 4 | adrar
# Processing Record 14 of Set 4 | bereda
# Processing Record 15 of Set 4 | mount isa
# Processing Record 16 of Set 4 | newala
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | poronaysk
# Processing Record 19 of Set 4 | chivilcoy
# Processing Record 20 of Set 4 | jinchang
# Processing Record 21 of Set 4 | rawson
# Processing Record 22 of Set 4 | ulaangom
# Processing Record 23 of Set 4 | saint-joseph
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | dicabisagan
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | innisfail
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | nuuk
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | castro
# Processing Record 36 of Set 4 | belaya gora
# Processing Record 37 of Set 4 | banjar
# Processing Record 38 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 4 | ritchie
# Processing Record 40 of Set 4 | lazaro cardenas
# Processing Record 41 of Set 4 | egvekinot
# Processing Record 42 of Set 4 | donskoy
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | krasnoselkup
# Processing Record 45 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 4 | mecca
# Processing Record 47 of Set 4 | lufilufi
# Processing Record 48 of Set 4 | melfi
# Processing Record 49 of Set 4 | praia da vitoria
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | bukama
# Processing Record 3 of Set 5 | bozoum
# Processing Record 4 of Set 5 | faanui
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | colares
# Processing Record 9 of Set 5 | nagornyy
# Processing Record 10 of Set 5 | tromso
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | cayenne
# Processing Record 13 of Set 5 | butterworth
# Processing Record 14 of Set 5 | skelleftea
# Processing Record 15 of Set 5 | tura
# Processing Record 16 of Set 5 | alto araguaia
# Processing Record 17 of Set 5 | makaryev
# Processing Record 18 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | lityn
# Processing Record 21 of Set 5 | xichang
# Processing Record 22 of Set 5 | mayo
# Processing Record 23 of Set 5 | yerbogachen
# Processing Record 24 of Set 5 | necochea
# Processing Record 25 of Set 5 | mount gambier
# Processing Record 26 of Set 5 | korla
# Processing Record 27 of Set 5 | arrifes
# Processing Record 28 of Set 5 | marsa matruh
# Processing Record 29 of Set 5 | cacapava do sul
# Processing Record 30 of Set 5 | zwettl
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | kinshasa
# Processing Record 33 of Set 5 | waingapu
# Processing Record 34 of Set 5 | ebano
# City not found. Skipping...
# Processing Record 35 of Set 5 | kachug
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | santa maria
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | hirara
# Processing Record 41 of Set 5 | kayes
# Processing Record 42 of Set 5 | half moon bay
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | etchoropo
# Processing Record 45 of Set 5 | isangel
# Processing Record 46 of Set 5 | nipawin
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | darhan
# Processing Record 50 of Set 5 | hino
# Processing Record 1 of Set 6 | champerico
# Processing Record 2 of Set 6 | gawler
# Processing Record 3 of Set 6 | umm kaddadah
# Processing Record 4 of Set 6 | tilichiki
# Processing Record 5 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 9 of Set 6 | suda
# Processing Record 10 of Set 6 | caravelas
# Processing Record 11 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | opuwo
# Processing Record 14 of Set 6 | kupang
# Processing Record 15 of Set 6 | vigrestad
# Processing Record 16 of Set 6 | pangody
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | daru
# Processing Record 19 of Set 6 | riyadh
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | dhidhdhoo
# Processing Record 22 of Set 6 | broken hill
# Processing Record 23 of Set 6 | bonthe
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | salinopolis
# Processing Record 26 of Set 6 | farafangana
# Processing Record 27 of Set 6 | fort frances
# Processing Record 28 of Set 6 | naugarzan
# City not found. Skipping...
# Processing Record 29 of Set 6 | samarai
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | nova olimpia
# Processing Record 32 of Set 6 | russell
# Processing Record 33 of Set 6 | porbandar
# Processing Record 34 of Set 6 | vanimo
# Processing Record 35 of Set 6 | zhuhai
# Processing Record 36 of Set 6 | antananarivo
# Processing Record 37 of Set 6 | ibra
# Processing Record 38 of Set 6 | kangaatsiaq
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | norman wells
# Processing Record 42 of Set 6 | ingham
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | kamenka
# Processing Record 45 of Set 6 | ukiah
# Processing Record 46 of Set 6 | labuhan
# Processing Record 47 of Set 6 | coahuayana
# Processing Record 48 of Set 6 | azovo
# Processing Record 49 of Set 6 | tiznit
# Processing Record 50 of Set 6 | hualmay
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | zhezkazgan
# Processing Record 5 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 7 | luwuk
# Processing Record 7 of Set 7 | floro
# Processing Record 8 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 11 of Set 7 | bairiki
# Processing Record 12 of Set 7 | port moresby
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | novoagansk
# Processing Record 16 of Set 7 | qasigiannguit
# Processing Record 17 of Set 7 | kajaani
# Processing Record 18 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 7 | adet
# Processing Record 20 of Set 7 | kapuskasing
# Processing Record 21 of Set 7 | asfi
# Processing Record 22 of Set 7 | surt
# Processing Record 23 of Set 7 | mangrol
# Processing Record 24 of Set 7 | ewa beach
# Processing Record 25 of Set 7 | tecoanapa
# Processing Record 26 of Set 7 | xixiang
# Processing Record 27 of Set 7 | gusau
# Processing Record 28 of Set 7 | puerto escondido
# Processing Record 29 of Set 7 | piacabucu
# Processing Record 30 of Set 7 | lianzhou
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | kysyl-syr
# Processing Record 33 of Set 7 | narasannapeta
# Processing Record 34 of Set 7 | arraial do cabo
# Processing Record 35 of Set 7 | javanrud
# Processing Record 36 of Set 7 | inegol
# Processing Record 37 of Set 7 | gubkinskiy
# Processing Record 38 of Set 7 | hastings
# Processing Record 39 of Set 7 | januaria
# Processing Record 40 of Set 7 | schrobenhausen
# Processing Record 41 of Set 7 | srandakan
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 44 of Set 7 | goderich
# Processing Record 45 of Set 7 | hasaki
# Processing Record 46 of Set 7 | dzilam gonzalez
# Processing Record 47 of Set 7 | guiratinga
# Processing Record 48 of Set 7 | saint-pierre
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | blyznyuky
# Processing Record 1 of Set 8 | kavieng
# Processing Record 2 of Set 8 | kuhestan
# City not found. Skipping...
# Processing Record 3 of Set 8 | hervey bay
# Processing Record 4 of Set 8 | moyale
# Processing Record 5 of Set 8 | camaqua
# Processing Record 6 of Set 8 | saint-augustin
# Processing Record 7 of Set 8 | acapulco
# Processing Record 8 of Set 8 | saskylakh
# Processing Record 9 of Set 8 | acajutla
# Processing Record 10 of Set 8 | port hardy
# Processing Record 11 of Set 8 | namatanai
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | cochabamba
# Processing Record 14 of Set 8 | susangerd
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | whitehorse
# Processing Record 17 of Set 8 | berlevag
# Processing Record 18 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 8 | dawei
# Processing Record 20 of Set 8 | cantagallo
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | golynki
# Processing Record 23 of Set 8 | yakeshi
# Processing Record 24 of Set 8 | evanston
# Processing Record 25 of Set 8 | oranjestad
# Processing Record 26 of Set 8 | matamoros
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | kroya
# Processing Record 29 of Set 8 | peoria
# Processing Record 30 of Set 8 | christchurch
# Processing Record 31 of Set 8 | naranjos
# Processing Record 32 of Set 8 | skjervoy
# Processing Record 33 of Set 8 | apiai
# Processing Record 34 of Set 8 | bako
# Processing Record 35 of Set 8 | salalah
# Processing Record 36 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 8 | sao filipe
# Processing Record 38 of Set 8 | westport
# Processing Record 39 of Set 8 | tornio
# Processing Record 40 of Set 8 | plastun
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | ejura
# Processing Record 43 of Set 8 | quatre cocos
# Processing Record 44 of Set 8 | butembo
# Processing Record 45 of Set 8 | severo-kurilsk
# Processing Record 46 of Set 8 | puerto suarez
# Processing Record 47 of Set 8 | stornoway
# Processing Record 48 of Set 8 | ati
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | kutum
# Processing Record 1 of Set 9 | pauini
# Processing Record 2 of Set 9 | boissevain
# Processing Record 3 of Set 9 | havelock
# Processing Record 4 of Set 9 | esso
# Processing Record 5 of Set 9 | eyl
# Processing Record 6 of Set 9 | nyurba
# Processing Record 7 of Set 9 | garwa
# Processing Record 8 of Set 9 | yatou
# Processing Record 9 of Set 9 | celestun
# Processing Record 10 of Set 9 | porto walter
# Processing Record 11 of Set 9 | mae sot
# Processing Record 12 of Set 9 | pringsewu
# Processing Record 13 of Set 9 | katobu
# Processing Record 14 of Set 9 | chunskiy
# Processing Record 15 of Set 9 | inuvik
# Processing Record 16 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 9 | dubrovnik
# Processing Record 18 of Set 9 | cockburn town
# Processing Record 19 of Set 9 | thinadhoo
# Processing Record 20 of Set 9 | xining
# Processing Record 21 of Set 9 | bubaque
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | agadir
# Processing Record 24 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 9 | namie
# Processing Record 26 of Set 9 | zaruma
# Processing Record 27 of Set 9 | constantine
# Processing Record 28 of Set 9 | carroll
# Processing Record 29 of Set 9 | sola
# Processing Record 30 of Set 9 | vathi
# Processing Record 31 of Set 9 | jumla
# Processing Record 32 of Set 9 | pimentel
# Processing Record 33 of Set 9 | north bend
# Processing Record 34 of Set 9 | bambous virieux
# Processing Record 35 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 9 | almaznyy
# Processing Record 37 of Set 9 | khandagayty
# Processing Record 38 of Set 9 | sao borja
# Processing Record 39 of Set 9 | aklavik
# Processing Record 40 of Set 9 | quang ngai
# Processing Record 41 of Set 9 | lugovoy
# Processing Record 42 of Set 9 | revadanda
# Processing Record 43 of Set 9 | mittersill
# Processing Record 44 of Set 9 | tanhacu
# Processing Record 45 of Set 9 | vila franca de xira
# Processing Record 46 of Set 9 | qaqortoq
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 9 | san andres
# Processing Record 50 of Set 9 | ambilobe
# Processing Record 1 of Set 10 | kavakli
# Processing Record 2 of Set 10 | mamakan
# Processing Record 3 of Set 10 | abalak
# Processing Record 4 of Set 10 | eenhana
# Processing Record 5 of Set 10 | sehithwa
# Processing Record 6 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 7 of Set 10 | xai-xai
# Processing Record 8 of Set 10 | saint anthony
# Processing Record 9 of Set 10 | sistranda
# Processing Record 10 of Set 10 | marzuq
# Processing Record 11 of Set 10 | bol
# Processing Record 12 of Set 10 | oswego
# Processing Record 13 of Set 10 | luyang
# Processing Record 14 of Set 10 | steinbach
# Processing Record 15 of Set 10 | yenagoa
# Processing Record 16 of Set 10 | otane
# Processing Record 17 of Set 10 | victor harbor
# Processing Record 18 of Set 10 | walvis bay
# Processing Record 19 of Set 10 | carauari
# Processing Record 20 of Set 10 | verkhniye kigi
# Processing Record 21 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 10 | kiunga
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | bakchar
# Processing Record 25 of Set 10 | beyneu
# Processing Record 26 of Set 10 | san policarpo
# Processing Record 27 of Set 10 | lavrentiya
# Processing Record 28 of Set 10 | hoquiam
# Processing Record 29 of Set 10 | shimanovsk
# Processing Record 30 of Set 10 | coihueco
# Processing Record 31 of Set 10 | kampli
# Processing Record 32 of Set 10 | wanlaweyn
# Processing Record 33 of Set 10 | armidale
# Processing Record 34 of Set 10 | barcelos
# Processing Record 35 of Set 10 | koslan
# Processing Record 36 of Set 10 | buala
# Processing Record 37 of Set 10 | homer
# Processing Record 38 of Set 10 | bloomington
# Processing Record 39 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 10 | kailua
# Processing Record 41 of Set 10 | totness
# Processing Record 42 of Set 10 | scarborough
# Processing Record 43 of Set 10 | south sioux city
# Processing Record 44 of Set 10 | teacapan
# Processing Record 45 of Set 10 | astoria
# Processing Record 46 of Set 10 | baykit
# Processing Record 47 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 10 | ust-kuyga
# Processing Record 50 of Set 10 | atbasar
# Processing Record 1 of Set 11 | shizunai
# Processing Record 2 of Set 11 | bushenyi
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | clyde river
# Processing Record 5 of Set 11 | orotukan
# Processing Record 6 of Set 11 | asosa
# Processing Record 7 of Set 11 | byron bay
# Processing Record 8 of Set 11 | jorpeland
# Processing Record 9 of Set 11 | la asuncion
# Processing Record 10 of Set 11 | saryg-sep
# Processing Record 11 of Set 11 | honningsvag
# Processing Record 12 of Set 11 | skegness
# Processing Record 13 of Set 11 | saint-paul
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | paita
# Processing Record 16 of Set 11 | burnie
# Processing Record 17 of Set 11 | port augusta
# Processing Record 18 of Set 11 | myaundzha
# Processing Record 19 of Set 11 | disna
# Processing Record 20 of Set 11 | tukrah
# Processing Record 21 of Set 11 | mahibadhoo
# Processing Record 22 of Set 11 | la cruz
# Processing Record 23 of Set 11 | road town
# Processing Record 24 of Set 11 | enshi
# Processing Record 25 of Set 11 | marang
# Processing Record 26 of Set 11 | bonga
# Processing Record 27 of Set 11 | khani
# Processing Record 28 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 29 of Set 11 | sungaipenuh
# Processing Record 30 of Set 11 | kruisfontein
# Processing Record 31 of Set 11 | hami
# Processing Record 32 of Set 11 | brae
# Processing Record 33 of Set 11 | atchison
# Processing Record 34 of Set 11 | agirish
# Processing Record 35 of Set 11 | vernon
# Processing Record 36 of Set 11 | rodrigues alves
# Processing Record 37 of Set 11 | sinazongwe
# Processing Record 38 of Set 11 | marrakesh
# Processing Record 39 of Set 11 | la plata
# Processing Record 40 of Set 11 | rio grande
# Processing Record 41 of Set 11 | gizo
# Processing Record 42 of Set 11 | tombouctou
# Processing Record 43 of Set 11 | wajir
# Processing Record 44 of Set 11 | sun valley
# Processing Record 45 of Set 11 | srbac
# Processing Record 46 of Set 11 | warmbad
# Processing Record 47 of Set 11 | hammerfest
# Processing Record 48 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 49 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 11 | aligudarz
# Processing Record 1 of Set 12 | deer lake
# Processing Record 2 of Set 12 | tangzhai
# Processing Record 3 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | tanout
# Processing Record 6 of Set 12 | dwarka
# Processing Record 7 of Set 12 | pochutla
# Processing Record 8 of Set 12 | arica
# Processing Record 9 of Set 12 | tessalit
# Processing Record 10 of Set 12 | fort nelson
# Processing Record 11 of Set 12 | eureka
# Processing Record 12 of Set 12 | tomatlan
# Processing Record 13 of Set 12 | mandalgovi
# Processing Record 14 of Set 12 | lewisporte
# Processing Record 15 of Set 12 | kindu
# Processing Record 16 of Set 12 | nantucket
# Processing Record 17 of Set 12 | monte patria
# Processing Record 18 of Set 12 | gamba
# Processing Record 19 of Set 12 | bitung
# Processing Record 20 of Set 12 | kargasok
# Processing Record 21 of Set 12 | iraquara
# Processing Record 22 of Set 12 | naze
# Processing Record 23 of Set 12 | bilma
# Processing Record 24 of Set 12 | teguldet
# Processing Record 25 of Set 12 | navahrudak
# Processing Record 26 of Set 12 | huilong
# Processing Record 27 of Set 12 | vazante
# Processing Record 28 of Set 12 | zeya
# Processing Record 29 of Set 12 | sobolevo
# Processing Record 30 of Set 12 | stelnica
# Processing Record 31 of Set 12 | gwembe
# Processing Record 32 of Set 12 | bobicesti
# Processing Record 33 of Set 12 | sirjan
# Processing Record 34 of Set 12 | jardim
# Processing Record 35 of Set 12 | porto santo
# Processing Record 36 of Set 12 | carutapera
# Processing Record 37 of Set 12 | ust-maya
# Processing Record 38 of Set 12 | yunyang
# Processing Record 39 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 12 | milas
# Processing Record 41 of Set 12 | aborlan
# Processing Record 42 of Set 12 | zabol
# Processing Record 43 of Set 12 | azusa
# Processing Record 44 of Set 12 | winslow
# Processing Record 45 of Set 12 | taltal
# Processing Record 46 of Set 12 | songea
# Processing Record 47 of Set 12 | thohoyandou
# Processing Record 48 of Set 12 | savelugu
# Processing Record 49 of Set 12 | urumqi
# Processing Record 50 of Set 12 | dargaville
# Processing Record 1 of Set 13 | pahrump
# Processing Record 2 of Set 13 | tsiroanomandidy
# Processing Record 3 of Set 13 | chernigovka
# Processing Record 4 of Set 13 | kovernino
# Processing Record 5 of Set 13 | rocha
# Processing Record 6 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 13 | codajas
# Processing Record 8 of Set 13 | cervo
# Processing Record 9 of Set 13 | mumford
# Processing Record 10 of Set 13 | otanche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 559

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Chuy -33.6971  -53.4616     79.20        75          90       11.30
# 1    Hermanus -34.4187   19.2345     69.80        87           1        3.15
# 2   Jamestown  42.0970  -79.2353     27.99        72         100       16.11
# 3   Cape Town -33.9258   18.4232     69.91        73           6       15.01
# 4   Maniitsoq  65.4167  -52.9000     19.76        66         100       13.29
# 5    Itaituba  -4.2761  -55.9836     78.67        94          64        3.36
# 6    Tasiilaq  65.6145  -37.6368     19.56        60         100        8.23
# 7     Mataura -46.1927  168.8643     56.70        54           0        4.21
# 8        Hilo  19.7297 -155.0900     76.62        82          75        3.44
# 9  Chokurdakh  70.6333  147.9167    -22.05        97           6        9.15
#
#   Country    Desc
# 0      UY  Clouds
# 1      ZA   Clear
# 2      US  Clouds
# 3      ZA   Clear
# 4      GL  Clouds
# 5      BR  Clouds
# 6      GL    Snow
# 7      NZ   Clear
# 8      US    Rain
# 9      RU   Clear

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Desc'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Desc']]

city_data_df.head()

#I UNDERSTAND THE ASK IS FOR ADDITIONAL STEPS HERE BUT JUST REORDERING THE EXISTING DATAFRAME SEEMS CLEANER AND FASTER, SO I OPTED FOR THAT.
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Chuy      UY -33.6971 -53.4616     79.20        75          90
# 1   Hermanus      ZA -34.4187  19.2345     69.80        87           1
# 2  Jamestown      US  42.0970 -79.2353     27.99        72         100
# 3  Cape Town      ZA -33.9258  18.4232     69.91        73           6
# 4  Maniitsoq      GL  65.4167 -52.9000     19.76        66         100
#
#    Wind Speed    Desc
# 0       11.30  Clouds
# 1        3.15   Clear
# 2       16.11  Clouds
# 3       15.01   Clear
# 4       13.29  Clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Desc           object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
export_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(export_file, index_label="City ID")
